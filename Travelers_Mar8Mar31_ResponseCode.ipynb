# %%
import requests
import pandas as pd
import spacy
import numpy as np

nlp = spacy.load('en')
headers = {'x-api-key': 'XoRXzfT62FxwRMcXjVKvw5efKaozQWncFfZjgd8M'}
 
def try_urls(url):
    try:
        response=requests.get(url)
    except:
        response='error'
   
    return response

# %%
data=pd.read_excel('/users/riya/documents/Coding/Travelers/TravelersNew.xlsx')
clean=pd.DataFrame(data)
clean
# Out:
#                                                    url
# 0    https://www.finder.com/car-insurance/farmers-v...
# 1    http://www.magnifymoney.com/blog/credit-cards-...
# 2    https://www.fortunebuilders.com/literally-ever...
# 3    http://www.autofocus.ca/news-events/latest-new...
# 4    http://www.adweek.com/agencyspy/thursday-odds-...
# 5    https://www.buzzfeed.com/geico/pick-some-novel...
# 6    https://www.supermoney.com/2018/03/lemonade-re...
# 7    https://www.supermoney.com/2018/03/nj-manufact...
# 8    https://www.ripoffreport.com/reports/relevant/...
# 9    http://www.spoke.com/press_releases/5aa136cfb0...
# 10        https://kilativ.livejournal.com/2596881.html
# 11   http://cs.trains.com/members/cheap-car-insuran...
# 12   http://www.shootonline.com/video/randy-krallma...
# 13   https://www.pymnts.com/news/cross-border-comme...
# 14   http://us.pressfrom.com/autos/buying/-125480-l...
# 15   http://us.pressfrom.com/autos/buying/-125480-l...
# ...

# %%
clean.columns
# Out:
# Index(['url'], dtype='object')

# %%
sample=clean.head(478)
a=sample['url'].apply(try_urls)
print(a)
# Out:
# 0      <Response [200]>
# 1      <Response [200]>
# 2      <Response [200]>
# 3      <Response [200]>
# 4      <Response [403]>
# 5      <Response [200]>
# 6      <Response [200]>
# 7      <Response [200]>
# 8      <Response [200]>
# 9      <Response [200]>
# 10     <Response [200]>
# 11     <Response [200]>
# 12     <Response [200]>
# 13     <Response [200]>
# 14     <Response [200]>
# 15     <Response [200]>
# 16     <Response [200]>
# 17     <Response [200]>
# 18     <Response [200]>
# 19     <Response [200]>
# 20     <Response [200]>
# 21     <Response [200]>
# 22     <Response [200]>
# 23     <Response [200]>
# 24     <Response [200]>
# 25     <Response [200]>
# 26     <Response [200]>
# 27     <Response [200]>
# 28     <Response [200]>
# 29     <Response [200]>
#              ...
# 447    <Response [200]>
# 448    <Response [200]>
# 449    <Response [200]>
# 450    <Response [200]>
# 451    <Response [200]>
# 452    <Response [200]>
# 453    <Response [200]>
# ...

# %%
sample['Response']=a
sample
a.to_csv("travelersnewurlresponse.csv")
# Out:
# /Users/riya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
