# %%
import requests
import pandas as pd
import spacy
import numpy as np

nlp = spacy.load('en')
headers = {'x-api-key': 'XoRXzfT62FxwRMcXjVKvw5efKaozQWncFfZjgd8M'}
 
def try_urls(url):
    try:
        response=requests.get(url)
    except:
        response='error'
   
    return response

# %%
data=pd.read_excel('/users/riya/documents/Coding/Travelers/TravelersNew.xlsx')
clean=pd.DataFrame(data)
clean
# Out:
#                                                    url
# 0    https://www.supermoney.com/2018/03/lemonade-re...
# 1    https://www.supermoney.com/2018/03/nj-manufact...
# 2    https://www.ripoffreport.com/reports/relevant/...
# 3    http://www.spoke.com/press_releases/5aa136cfb0...
# 4    https://insurancenewsnet.com/oarticle/high-ded...
# 5    https://insurancenewsnet.com/oarticle/how-to-f...
# 6    http://www.spoke.com/press_releases/5aa2bb30b0...
# 7    http://www.benzinga.com/pressreleases/18/03/n1...
# 8    http://markets.financialcontent.com/stocks/new...
# 9    http://www.spoke.com/press_releases/5aa288242c...
# 10   http://markets.financialcontent.com/stocks/new...
# 11       http://www.lelezard.com/en/news-16299542.html
# 12   http://www.spoke.com/press_releases/5aa3d7c4b2...
# 13   http://www.benzinga.com/pressreleases/18/03/n1...
# 14   http://markets.financialcontent.com/stocks/new...
# 15       http://www.lelezard.com/en/news-16303212.html
# 16   http://www.spoke.com/press_releases/5aa6cf4d2c...
# 17   http://www.benzinga.com/pressreleases/18/03/n1...
# 18   https://insurancenewsnet.com/oarticle/what-to-...
# 19   http://markets.financialcontent.com/stocks/new...
# 20   http://www.spoke.com/press_releases/5aa6c9382c...
# 21   http://www.spoke.com/press_releases/5aa6c9382c...
# 22   http://www.benzinga.com/pressreleases/18/03/n1...
# 23   https://insurancenewsnet.com/oarticle/how-to-f...
# 24   http://markets.financialcontent.com/stocks/new...
# 25   http://www.benzinga.com/pressreleases/18/03/n1...
# 26   http://markets.financialcontent.com/stocks/new...
# 27   http://www.benzinga.com/pressreleases/18/03/n1...
# 28   http://markets.financialcontent.com/stocks/new...
# 29   https://insurancenewsnet.com/oarticle/common-c...
# ..                                                 ...
# 227  https://insurancenewsnet.com/oarticle/higher-e...
# 228  http://markets.financialcontent.com/stocks/new...
# 229  http://www.benzinga.com/pressreleases/18/03/r1...
# 230  https://insurancenewsnet.com/oarticle/why-you-...
# 231  http://insurancethoughtleadership.com/how-insu...
# 232  http://www.spoke.com/press_releases/5abe8a4c2c...
# 233  http://www.spoke.com/press_releases/5abe8a4c2c...
# 234  http://www.benzinga.com/pressreleases/18/03/r1...
# 235  http://markets.financialcontent.com/stocks/new...
# 236  http://www.benzinga.com/pressreleases/18/03/r1...
# 237  https://insurancenewsnet.com/oarticle/what-is-...
# 238  http://markets.financialcontent.com/stocks/new...
# 239  https://insurancenewsnet.com/oarticle/how-can-...
# 240  https://insurancenewsnet.com/oarticle/what-is-...
# 241  http://www.spoke.com/press_releases/5abe43fd2c...
# 242  https://www.benzinga.com/pressreleases/18/03/r...
# 243  http://markets.financialcontent.com/stocks/new...
# 244  http://www.spoke.com/press_releases/5abe35ed2c...
# 245  http://www.benzinga.com/pressreleases/18/03/r1...
# 246  https://insurancenewsnet.com/oarticle/auto-ins...
# 247  http://markets.financialcontent.com/stocks/new...
# 248      http://www.lelezard.com/en/news-16497922.html
# 249      http://www.lelezard.com/en/news-16498812.html
# 250      http://www.lelezard.com/en/news-16498852.html
# 251      http://www.lelezard.com/en/news-16497642.html
# 252  =HYPERLINK("http://app.trendkite.com/redir?s=8...
# 253  http://www.spoke.com/press_releases/5abf95732c...
# 254  https://insurancenewsnet.com/oarticle/drivers-...
# 255  http://markets.financialcontent.com/stocks/new...
# 256      http://www.lelezard.com/en/news-16499852.html
#
# [257 rows x 1 columns]

# %%
clean.columns
# Out:
# Index(['url'], dtype='object')

# %%
sample=clean.head(257)
a=sample['url'].apply(try_urls)
print(a)
# Out:
# 0      <Response [200]>
# 1      <Response [200]>
# 2      <Response [200]>
# 3      <Response [200]>
# 4      <Response [200]>
# 5      <Response [200]>
# 6      <Response [200]>
# 7      <Response [200]>
# 8      <Response [200]>
# 9      <Response [200]>
# 10     <Response [200]>
# 11     <Response [200]>
# 12     <Response [200]>
# 13     <Response [200]>
# 14     <Response [200]>
# 15     <Response [200]>
# 16     <Response [200]>
# 17     <Response [200]>
# 18     <Response [200]>
# 19     <Response [200]>
# 20     <Response [200]>
# 21     <Response [200]>
# 22     <Response [200]>
# 23     <Response [200]>
# 24     <Response [200]>
# 25     <Response [200]>
# 26     <Response [200]>
# 27     <Response [200]>
# 28     <Response [200]>
# 29     <Response [200]>
#              ...
# 227    <Response [200]>
# 228    <Response [200]>
# 229    <Response [200]>
# 230    <Response [200]>
# 231    <Response [200]>
# 232    <Response [200]>
# 233    <Response [200]>
# 234    <Response [200]>
# 235    <Response [200]>
# 236    <Response [200]>
# 237    <Response [200]>
# 238    <Response [200]>
# 239    <Response [200]>
# 240    <Response [200]>
# 241    <Response [200]>
# 242    <Response [200]>
# 243    <Response [200]>
# 244    <Response [200]>
# 245    <Response [200]>
# 246    <Response [200]>
# 247    <Response [200]>
# 248    <Response [200]>
# 249    <Response [200]>
# 250    <Response [200]>
# 251    <Response [200]>
# 252               error
# 253    <Response [200]>
# 254    <Response [200]>
# 255    <Response [200]>
# 256    <Response [200]>
# Name: url, Length: 257, dtype: object

# %%
sample['Response']=a
sample
a.to_csv("travelersnewurlresponse.csv")
# Out:
# /Users/riya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
