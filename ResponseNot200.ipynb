# %%
import requests
import pandas as pd
import spacy
import numpy as np

nlp = spacy.load('en')
headers = {'x-api-key': 'XoRXzfT62FxwRMcXjVKvw5efKaozQWncFfZjgd8M'}

def url_to_call(url):
    mercury='https://mercury.postlight.com/parser?url='
    try:
        total_url = '{0}{1}'.format(mercury, url)
        call = requests.get(total_url, headers=headers)
    except:
        call = 'error'
       
    return call

# %%
data=pd.read_excel('/users/riya/documents/Coding/Travelers.xlsx')
clean=pd.DataFrame(data)
clean
# Out:
#                                                     URL
# 0     http://www.wgr550.com/media/audio-channel/01-0...
# 1     http://www.wgr550.com/media/audio-channel/01-0...
# 2     https://www.inc.com/jonathan-alpert/do-these-1...
# 3     http://lifeandmyfinances.com/2018/01/10-ways-t...
# 4     https://dealspotr.com/article/discounts-for-ve...
# 5     https://www.offers.com/blog/post/college-stude...
# 6     http://www.wgr550.com/media/audio-channel/1-1-...
# 7     http://www.wgr550.com/media/audio-channel/1-1-...
# 8     https://www.buzzfeed.com/alejandrabcruz/16-twe...
# 9     https://www.buzzfeed.com/ryanschocket2/sixteen...
# 10    https://www.buzzfeed.com/crystalro/dora-milaje...
# 11    https://www.buzzfeed.com/hattiesoykan/moments-...
# 12    http://www.spoke.com/press_releases/5a4e26f0b8...
# 13    http://markets.financialcontent.com/stocks/new...
# 14        http://www.lelezard.com/en/news-15690582.html
# 15    https://www.nawbo.org/nawbo-institute/2017-201...
# ...

# %%
clean.columns
# Out:
# Index(['URL'], dtype='object')

# %%
sample=clean.tail(100)
b=sample['URL'].apply(url_to_call)
print(b)
# Out:
# 1105    <Response [200]>
# 1106    <Response [200]>
# 1107    <Response [200]>
# 1108    <Response [200]>
# 1109    <Response [200]>
# 1110    <Response [200]>
# 1111    <Response [200]>
# 1112    <Response [200]>
# 1113    <Response [200]>
# 1114    <Response [200]>
# 1115    <Response [200]>
# 1116    <Response [200]>
# 1117    <Response [200]>
# 1118    <Response [200]>
# 1119    <Response [200]>
# 1120    <Response [200]>
# 1121    <Response [200]>
# 1122    <Response [200]>
# 1123    <Response [200]>
# 1124    <Response [200]>
# 1125    <Response [200]>
# 1126    <Response [200]>
# 1127    <Response [200]>
# 1128    <Response [200]>
# 1129    <Response [200]>
# 1130    <Response [502]>
# 1131    <Response [200]>
# 1132    <Response [200]>
# 1133    <Response [200]>
# 1134    <Response [200]>
#               ...
# 1175    <Response [200]>
# 1176    <Response [200]>
# 1177    <Response [200]>
# 1178    <Response [200]>
# 1179    <Response [200]>
# 1180    <Response [200]>
# ...

# %%
sample['Response']=b
sample
# Out:
# /Users/riya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                                     URL          Response
# 1105  http://news3lv.com/news/local/unoccupied-homes...  <Response [200]>
# 1106  https://www.newsmax.com/finance/maximerieman/c...  <Response [200]>
# 1107  http://www.kyma.com/news/economy/do-you-text-a...  <Response [200]>
# 1108  http://www.kvia.com/news/economy/do-you-text-a...  <Response [200]>
# 1109  https://insurancenewsnet.com/oarticle/usage-ba...  <Response [200]>
# 1110  http://www.sbwire.com/press-releases/usage-bas...  <Response [200]>
# ...

# %%
b.to_csv("travelersurl.csv")

# %%
# def trash(URL):
#     if sample['URL'].status_code==200:
#         sample['Trash']=sample.apply('0')
#         return sample['Trash']
#     else:
#         sample['Trash']=sample.apply('1')
#         return sample['Trash']
